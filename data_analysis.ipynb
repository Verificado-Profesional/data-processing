# %% [markdown]
# ## **Análisis y recopilación de Noticias Falsas**

# %% [markdown]
# En este Notebook vamos a estar analizando y recopilando información noticias falsas en español. En primer lugar, se hara un estudio de distintos datasets encontrados en la nube.Luego vamos a analizar una gran variedad de datos obtenidos de paginas de fact-checking mediante la tecnica de web scrapping. Finalmente se busca unificar toda la informacion para contar con un corpus robusto de noticias falsas en español.
#
# A modo de estandarizar la informacion, se cambiara las labels de la siguiente manera en caso de que corresponda:
#
# * True : 1
# * False : 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
from unidecode import unidecode

# %% [markdown]
# ##  **1. Análisis Dataset final**

# %% [markdown]
# ##### **Cantidad de valores totales:**

# %%
data = pd.read_csv("data.csv")
data.shape
# Out:
# (62972, 9)

# %% [markdown]
# ##### **Cantidad de nulos por columna:**

# %%
data.isnull().sum()
# Out:
# Categoria        0
# Titulo        3168
# Texto            0
# Fecha         5741
# Origen           0
# id           61429
# Topico       61429
# Fuente       61436
# URL          61432
# dtype: int64

# %%
tf_count = data["Categoria"].value_counts()
tf_count
# Out:
# Categoria
# 1    36267
# 0    26705
# Name: count, dtype: int64

# %% [markdown]
# ##### **Cantidad de noticias Falsas y Verdaderas**

# %%
plt.figure(figsize=(15,10))
plt.pie(tf_count, labels=["true", "fake"],autopct="%1.f%%", colors=["skyblue", "crimson"])

plt.title("Cantidad de noticias verdaderas y falsas")

plt.show()

# %% [markdown]
# ##### **Cantidad de noticias Falsas y Verdaderas por Origen**

# %%
count_per_origen_categoria = data.groupby(['Origen', 'Categoria']).size().reset_index(name='Count').sort_values(by="Count")
count_per_origen_categoria
# Out:
#     Origen  Categoria  Count
# 2   Madrid          0    259
# 3   Madrid          1    339
# 4  Posadas          0    766
# 5  Posadas          1    777
# 0   Kaggle          0   1800
# 1   Kaggle          1   1800
# 6     Vigo          0  23880
# 7     Vigo          1  33351

# %%
# Graficar la cantidad de noticias por año y clasificación
colores = {1: 'skyblue', 0: 'crimson'}
plt.figure(figsize=(12, 6))
data.groupby(['Origen', 'Categoria']).size().unstack().plot(kind='bar', stacked=False, color=[colores[c] for c in count_per_origen_categoria['Categoria']])
plt.title('Cantidad de Noticias por Origen y Clasificación')
plt.xlabel('Origen')
plt.ylabel('Número de Noticias')
plt.yscale('log')
plt.legend(title='Clasificación')
plt.show()

# %% [markdown]
# ##### **Cantidad de noticias por fuente**

# %%
data['Fuente_Normalizada'] = data['Fuente'].apply(lambda x: unidecode(str(x).lower()) if not pd.isna(x) else pd.NA)

plt.figure(figsize=(10, 6))  # Ajusta el tamaño según sea necesario
data.groupby('Fuente_Normalizada').size().sort_values(ascending=False).head(15).plot(kind='bar', color='orange',)
plt.title('Top 15 Fuentes con más noticias')
plt.ylabel('Número de Noticias')
plt.xlabel('Fuente')
plt.show()

# %% [markdown]
# ##### **Top fuentes con más noticias falsas**

# %%
data_categoria_0 = data[data['Categoria'] == 0]
plt.figure(figsize=(10, 6))  # Ajusta el tamaño según sea necesario
data_categoria_0.groupby('Fuente_Normalizada').size().sort_values(ascending=False).head(15).plot(kind='bar', color='crimson',)
plt.title('Top 15 Fuentes con más noticias')
plt.ylabel('Número de Noticias Falsas')
plt.xlabel('Fuente')
plt.show()

# %% [markdown]
# ##### **Top fuentes con más noticias verdaderas**

# %%
data_categoria_1 = data[data['Categoria'] == 1]
plt.figure(figsize=(10, 6))  # Ajusta el tamaño según sea necesario
data_categoria_1.groupby('Fuente_Normalizada').size().sort_values(ascending=False).head(15).plot(kind='bar', color='skyblue',)
plt.title('Top 15 Fuentes con más noticias')
plt.ylabel('Número de Noticias Verdaderas')
plt.xlabel('Fuente')
plt.show()

# %% [markdown]
# ##### **Cantidad de noticias verdaderas y falsas por año**

# %%
data['Fecha'] = pd.to_datetime(data['Fecha'])

# Obtener la fecha más antigua y la fecha más reciente
fecha_mas_antigua = data['Fecha'].min()
fecha_mas_reciente = data['Fecha'].max()

[fecha_mas_antigua, fecha_mas_reciente]
# Out:
# /var/folders/x_/90gbdtf13xq_0ggch_9jnn2w0000gn/T/ipykernel_4403/2607816148.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Fecha'] = pd.to_datetime(data['Fecha'])
# [Timestamp('2017-04-24 00:00:00'), Timestamp('2023-12-28 00:00:00')]

# %%
data['Fecha'] = pd.to_datetime(data['Fecha'])

# Obtener el año de cada noticia
data['Anio'] = data['Fecha'].dt.year
data_for_graph = data[data['Anio'] != 2017]

colores = {1: 'skyblue', 0: 'crimson'}
# Graficar la cantidad de noticias por año y clasificación
plt.figure(figsize=(12, 6))
data_for_graph.groupby(['Anio', 'Categoria']).size().unstack().plot(kind='bar', stacked=False, color=colores)
plt.title('Cantidad de Noticias por Año y Clasificación')
plt.xlabel('Año de Publicación')
plt.ylabel('Número de Noticias')
plt.legend(title='Clasificación')
plt.show()

# %% [markdown]
# ## **2. Preparación y limpieza de dataset final**

# %% [markdown]
# ##### **Dropear columnas nulas**

# %%
data_procesada = data.drop(columns=["id", "Topico", "Fuente", "URL"])
data_procesada
# Out:
#        Categoria                                             Titulo  \
# 0              1  Moreno intenta apaciguar el flanco sanitario m...
# 1              1  La Abogacía del Estado se retira como acusació...
# 2              0  Las promesas incumplidas de Pablo Echenique en...
# 3              1  Sánchez defiende 'resolver el problema' de la ...
# 4              1  Ian Gibson cierra la lista electoral de la con...
# ...          ...                                                ...
# 62967          0  Madonna será la nueva imagen del Chocolate Abu...
# 62968          1  Filtran material íntimo de Zelina Vega, luchad...
# 62969          0  CBS PLANEA GRAN HERMANO EN LA CASA BLANCA CON ...
# 62970          0  TV Azteca anuncia que cambiará su nombre por u...
# 62971          0          MUERTE DE PETER EL ANGUILA POR SOBREDOSIS
#
#                                                    Texto      Fecha   Origen  \
# 0      El presidente abre la puerta a unos comicios e... 2022-04-19     Vigo
# 1      En un escrito, la abogada del Estado Rosa Marí... 2021-09-17     Vigo
# 2      Este lunes y martes la Asamblea de Madrid acog... 2022-09-12     Vigo
# 3      Resulta evidente que la ley ha tenido algunos ... 2023-02-07     Vigo
# 4      El hispanista, que ya ocupó un puesto simbólic... 2023-04-12     Vigo
# ...                                                  ...        ...      ...
# 62967  Madonna será la nueva imagen del Chocolate Abu...        NaT  Posadas
# 62968  Filtran material íntimo de Zelina Vega, luchad...        NaT  Posadas
# 62969  CBS PLANEA GRAN HERMANO EN LA CASA BLANCA CON ...        NaT  Posadas
# 62970  TV Azteca anuncia que cambiará su nombre por u...        NaT  Posadas
# 62971  MUERTE DE PETER EL ANGUILA POR SOBREDOSIS\nPet...        NaT  Posadas
#
#       Fuente_Normalizada    Anio
# 0                    NaN  2022.0
# 1                    NaN  2021.0
# 2                    NaN  2022.0
# 3                    NaN  2023.0
# 4                    NaN  2023.0
# ...                  ...     ...
# 62967          el dizque     NaN
# 62968      radio formula     NaN
# 62969     la voz popular     NaN
# 62970          el dizque     NaN
# 62971     la voz popular     NaN
#
# [62972 rows x 7 columns]

# %%
data_procesada['Noticia'] = data_procesada['Titulo'].fillna('').str.upper() + '\n' + data_procesada['Texto']
data_procesada
# Out:
#        Categoria                                             Titulo  \
# 0              1  Moreno intenta apaciguar el flanco sanitario m...
# 1              1  La Abogacía del Estado se retira como acusació...
# 2              0  Las promesas incumplidas de Pablo Echenique en...
# 3              1  Sánchez defiende 'resolver el problema' de la ...
# 4              1  Ian Gibson cierra la lista electoral de la con...
# ...          ...                                                ...
# 62967          0  Madonna será la nueva imagen del Chocolate Abu...
# 62968          1  Filtran material íntimo de Zelina Vega, luchad...
# 62969          0  CBS PLANEA GRAN HERMANO EN LA CASA BLANCA CON ...
# 62970          0  TV Azteca anuncia que cambiará su nombre por u...
# 62971          0          MUERTE DE PETER EL ANGUILA POR SOBREDOSIS
#
#                                                    Texto      Fecha   Origen  \
# 0      El presidente abre la puerta a unos comicios e... 2022-04-19     Vigo
# 1      En un escrito, la abogada del Estado Rosa Marí... 2021-09-17     Vigo
# 2      Este lunes y martes la Asamblea de Madrid acog... 2022-09-12     Vigo
# 3      Resulta evidente que la ley ha tenido algunos ... 2023-02-07     Vigo
# 4      El hispanista, que ya ocupó un puesto simbólic... 2023-04-12     Vigo
# ...                                                  ...        ...      ...
# 62967  Madonna será la nueva imagen del Chocolate Abu...        NaT  Posadas
# 62968  Filtran material íntimo de Zelina Vega, luchad...        NaT  Posadas
# 62969  CBS PLANEA GRAN HERMANO EN LA CASA BLANCA CON ...        NaT  Posadas
# 62970  TV Azteca anuncia que cambiará su nombre por u...        NaT  Posadas
# 62971  MUERTE DE PETER EL ANGUILA POR SOBREDOSIS\nPet...        NaT  Posadas
#
#       Fuente_Normalizada    Anio  \
# 0                    NaN  2022.0
# 1                    NaN  2021.0
# 2                    NaN  2022.0
# 3                    NaN  2023.0
# 4                    NaN  2023.0
# ...                  ...     ...
# 62967          el dizque     NaN
# 62968      radio formula     NaN
# 62969     la voz popular     NaN
# 62970          el dizque     NaN
# 62971     la voz popular     NaN
#
#                                                  Noticia
# 0      MORENO INTENTA APACIGUAR EL FLANCO SANITARIO M...
# 1      LA ABOGACÍA DEL ESTADO SE RETIRA COMO ACUSACIÓ...
# 2      LAS PROMESAS INCUMPLIDAS DE PABLO ECHENIQUE EN...
# 3      SÁNCHEZ DEFIENDE 'RESOLVER EL PROBLEMA' DE LA ...
# 4      IAN GIBSON CIERRA LA LISTA ELECTORAL DE LA CON...
# ...                                                  ...
# 62967  MADONNA SERÁ LA NUEVA IMAGEN DEL CHOCOLATE ABU...
# 62968  FILTRAN MATERIAL ÍNTIMO DE ZELINA VEGA, LUCHAD...
# 62969  CBS PLANEA GRAN HERMANO EN LA CASA BLANCA CON ...
# 62970  TV AZTECA ANUNCIA QUE CAMBIARÁ SU NOMBRE POR U...
# 62971  MUERTE DE PETER EL ANGUILA POR SOBREDOSIS\nMUE...
#
# [62972 rows x 8 columns]

# %% [markdown]
# ### Modelo de Vectorización

# %%
import re
from stop_words import get_stop_words

# %%
stop_words_es = get_stop_words('es')
puntuaciones = "'.,;:\"()[]{}\\/?!-_*'"

def quitar_stop_words(texto):
    words = texto.split()
    result_words = [word for word in words if (word not in stop_words_es and word not in puntuaciones)]
    resultado = ' '.join(result_words)
    return resultado

def clean_comments(corpus):
    patt1 = re.compile('\d')
    patt2 = re.compile('\W')
    patt3 = re.compile('  *')

    corpus = corpus.lower()
    corpus = patt1.sub('', corpus)
    corpus = patt2.sub(' ', corpus)
    corpus = patt3.sub(' ', corpus)
    corpus = quitar_stop_words(corpus)
    return corpus

# %%
data_procesada['Texto_Limpio'] = data_procesada['Noticia'].apply(lambda x: clean_comments(x))

# %%
corpus = data_procesada['Texto_Limpio'].values
corpus[0]
# Out:
# 'moreno intenta apaciguar flanco sanitario mientras enreda fecha elecciones presidente abre puerta comicios junio domingo'

# %%
from nltk.tokenize import TweetTokenizer

tknzr = TweetTokenizer()
tknzr.tokenize(corpus[0])
# Out:
# ['moreno',
#  'intenta',
#  'apaciguar',
#  'flanco',
#  'sanitario',
#  'mientras',
#  'enreda',
#  'fecha',
#  'elecciones',
#  'presidente',
#  'abre',
#  'puerta',
#  'comicios',
#  'junio',
#  'domingo']

# %%
corpus_tk = []
for i in corpus:
    corpus_tk.append(tknzr.tokenize(i))

# %%
from gensim.models import Word2Vec
model = Word2Vec(corpus_tk, min_count=50, window=5, vector_size=100)
X = model.wv.vectors
X
# Out:
# array([[ 1.5483704 , -1.4640354 ,  0.5644442 , ...,  0.4026547 ,
#         -0.50154406,  0.39566046],
#        [ 1.2021531 , -1.7794317 , -0.46226448, ...,  1.4961089 ,
#         -0.95180917,  0.39066255],
#        [ 0.79730606, -1.1883916 , -1.3274182 , ..., -0.47765753,
#          1.890035  ,  0.07524038],
#        ...,
#        [ 0.03042814,  0.11723759, -0.01634   , ..., -0.23681083,
#         -0.13605331,  0.07539692],
#        [-0.21045804,  0.00973973,  0.1375675 , ..., -0.26729015,
#          0.22980231,  0.24470443],
#        [-0.2686015 ,  0.29275402, -0.136346  , ..., -0.3739115 ,
#         -0.2944338 , -0.3529124 ]], dtype=float32)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=50, svd_solver='full')
pca.fit(X)
plt.plot((pca.explained_variance_ratio_).cumsum())
plt.title('Variance_ratio')
plt.xlabel('PCA Components')
# Out:
# Text(0.5, 0, 'PCA Components')

# %%
pca = PCA(n_components=30, svd_solver='full')
pca.fit(X)
# Out:
# PCA(n_components=30, svd_solver='full')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=30)
TF_IDF = vectorizer.fit_transform(corpus)

# %%
TF_IDF.toarray().shape
# Out:
# (62972, 8235)

# %%
tf_idf = vectorizer.vocabulary_

# %%
tf_idf
# Out:
# {'moreno': 5084,
#  'intenta': 4245,
#  'sanitario': 7049,
#  'mientras': 4979,
#  'fecha': 3384,
#  'elecciones': 2751,
#  'presidente': 6058,
#  'abre': 34,
#  'puerta': 6343,
#  'comicios': 1510,
#  'junio': 4433,
#  'domingo': 2636,
#  'abogacía': 20,
#  'retira': 6828,
#  'acusación': 173,
#  'pieza': 5820,
#  'iberdrola': 3917,
#  'caso': 1215,
#  'tándem': 7760,
#  'escrito': 3005,
#  'abogada': 21,
#  'rosa': 6940,
#  'maría': 4857,
#  'argumenta': 632,
#  'decisión': 2178,
#  'falta': 3357,
#  'activa': 126,
#  'respecto': 6787,
#  'delitos': 2249,
#  'imputados': 4013,
#  'promesas': 6214,
#  'pablo': 5504,
#  'echenique': 2686,
#  'sanidad': 7046,
#  'educación': 2708,
#  'vivienda': 8079,
#  'lunes': 4710,
#  'martes': 4852,
#  'asamblea': 673,
#  'madrid': 4732,
#  'acogerá': 102,
#  'debate': 2141,
#  'región': 6653,
#  'último': 8227,
#  'celebró': 1281,
#  'hace': 3784,
#  'dos': 2646,
#  'años': 850,
#  'septiembre': 7140,
#  'sánchez': 7441,
#  'defiende': 2216,
#  'resolver': 6775,
#  'problema': 6153,
#  'ley': 4563,
#  'solo': 7287,
#  'diálogo': 2618,
#  'resulta': 6818,
#  'evidente': 3177,
#  'efectos': 2722,
#  'corto': 1933,
#  'destacado': 2395,
#  'gobierno': 3689,
#  'diputados': 2531,
#  'senadores': 7111,
#  'cierra': 1363,
#  'lista': 4607,
#  'electoral': 2755,
#  'confluencia': 1688,
#  'podemos': 5886,
#  'granada': 3714,
#  'ocupó': 5388,
#  'puesto': 6349,
#  'simbólico': 7213,
#  'anteriores': 480,
#  'municipales': 5134,
#  'recalcado': 6495,
#  'presencia': 6029,
#  'nuevo': 5320,
#  'debe': 2145,
#  'deseo': 2358,
#  'tener': 7516,
#  'verde': 7970,
#  'quiero': 6411,
#  'erc': 2966,
#  'junts': 4439,
#  'negociación': 5245,
#  'salvar': 7034,
#  'govern': 3701,
#  'empieza': 2818,
#  'intensa': 4242,
#  'semana': 7104,
#  'ejecutivo': 2734,
#  'catalán': 1232,
#  'ambos': 421,
#  'socios': 7266,
#  'continúan': 1836,
#  'negociaciones': 5244,
#  'acercar': 92,
#  'posiciones': 5958,
#  'presupuestos': 6089,
#  'catalanes': 1228,
#  'horizonte': 3888,
#  'momento': 5056,
#  'avances': 814,
#  'achaca': 94,
#  'republicanos': 6754,
#  'señalan': 7172,
#  'división': 2617,
#  'interna': 4265,
#  'primeros': 6123,
#  'pp': 5978,
#  'rinde': 6898,
#  'discurso': 2567,
#  'vox': 8120,
#  'pleno': 5870,
#  'año': 849,
#  'núñez': 5333,
#  'feijóo': 3390,
#  'guarda': 3737,
#  'silencio': 7207,
#  'ayuso': 840,
#  'almeida': 386,
#  'aprovechan': 591,
#  'polémica': 5910,
#  'asumir': 733,
#  'tesis': 7557,
#  'extrema': 3317,
#  'derecha': 2302,
#  'psoe': 6313,
#  'denuncia': 2273,
#  'hombre': 3869,
#  'mañueco': 4892,
#  'salamanca': 6999,
#  'utiliza': 7852,
#  'personal': 5772,
#  'limpieza': 4604,
#  'socialistas': 7261,
#  'trabajadores': 7640,
#  'edificios': 2702,
#  'dar': 2123,
#  'salida': 7013,
#  'propaganda': 6234,
#  'gestión': 3661,
#  'garcía': 3622,
#  'escrivá': 3009,
#  'niega': 5266,
#  'reforma': 6620,
#  'extranjería': 3313,
#  'efecto': 2721,
#  'llamada': 4613,
#  'sustitución': 7430,
#  'nacionales': 5189,
#  'ministro': 5007,
#  'inclusión': 4044,
#  'seguridad': 7096,
#  'social': 7256,
#  'migraciones': 4981,
#  'considera': 1757,
#  'modelo': 5039,
#  'crecimiento': 1967,
#  'económico': 2695,
#  'empleo': 2823,
#  'botella': 1015,
#  'iu': 4362,
#  'propone': 6244,
#  'ayuntamientos': 839,
#  'nueva': 5316,
#  'financiación': 3440,
#  'autonómica': 786,
#  'izquierda': 4365,
#  'unida': 7795,
#  'aprueba': 596,
#  'sábado': 7438,
#  'programa': 6198,
#  'marco': 4831,
#  'autonómicas': 787,
#  'alberto': 327,
#  'garzón': 3624,
#  'apuestan': 600,
#  'distribución': 2605,
#  'territorial': 7547,
#  'recursos': 6590,
#  'garantice': 3615,
#  'servicios': 7155,
#  'públicos': 6378,
#  'rescata': 6764,
#  'venezuela': 7950,
#  'temor': 7503,
#  'movilización': 5106,
#  'elegir': 2766,
#  'presidenta': 6057,
#  'madrileña': 4733,
#  'asegurado': 679,
#  'decisivo': 2177,
#  'quiere': 6408,
#  'cambiar': 1116,
#  'sociedad': 7262,
#  'entrar': 2925,
#  'instituciones': 4213,
#  'manera': 4776,
#  'después': 2391,
#  'días': 2678,
#  'santiago': 7055,
#  'abascal': 9,
#  'votar': 8112,
#  'sustituto': 7434,
#  'frente': 3533,
#  'bng': 983,
#  'febrero': 3383,
#  'salió': 7020,
#  'luz': 4712,
#  'presunto': 6082,
#  'espionaje': 3068,
#  'díaz': 2679,
#  'marzo': 4856,
#  'afiliados': 259,
#  'esquerra': 3074,
#  'republicana': 6751,
#  'catalunya': 1229,
#  'votado': 8108,
#  'belarra': 933,
#  'partido': 5622,
#  'sigue': 7201,
#  'mandos': 4770,
#  'génova': 3762,
#  'congreso': 1701,
#  'extraordinario': 3315,
#  'canarias': 1139,
#  'exige': 3227,
#  'dimisión': 2512,
#  'murcia': 5137,
#  'tras': 7683,
#  'parálisis': 5625,
#  'parlamentaria': 5593,
#  'provocada': 6286,
#  'eaj': 2683,
#  'pnv': 5876,
#  'oposición': 5453,
#  'pide': 5803,
#  'cese': 1326,
#  'castillo': 1224,
#  'decidido': 2167,
#  'suspender': 7424,
#  'junta': 4435,
#  'portavoces': 5941,
#  'solicitud': 7282,
#  'pascual': 5641,
#  'salvador': 7032,
#  'isabel': 4349,
#  'ingresar': 4144,
#  'grupo': 3732,
#  'mixto': 5032,
#  'salva': 7031,
#  'da': 2112,
#  'carpetazo': 1195,
#  'tensiones': 7520,
#  'aliados': 374,
#  'acuerda': 163,
#  'seguir': 7087,
#  'tramitación': 7659,
#  'gracias': 3709,
#  'apoyo': 573,
#  'bloque': 975,
#  'investidura': 4299,
#  'avisan': 828,
#  'darán': 2129,
#  'batalla': 917,
#  'mejorar': 4920,
#  'norma': 5296,
#  'mediante': 4902,
#  'enmiendas': 2894,
#  'parciales': 5580,
#  'registradas': 6643,
#  'mano': 4791,
#  'colectivos': 1465,
#  'líder': 4714,
#  'ione': 4330,
#  'albert': 326,
#  'noguera': 5285,
#  'media': 4899,
#  'equo': 2965,
#  'votación': 8106,
#  'fía': 3580,
#  'estrategia': 3117,
#  'fondo': 3473,
#  'avales': 810,
#  'tribunal': 7719,
#  'cuentas': 2036,
#  'consell': 1742,
#  'afectados': 248,
#  'últimas': 8226,
#  'horas': 3887,
#  'plazo': 5865,
#  'fianzas': 3410,
#  'dictamen': 2475,
#  'favorable': 3376,
#  'órgano': 8222,
#  'control': 1854,
#  'podría': 5895,
#  'facilitar': 3331,
#  'participación': 5605,
#  'banco': 880,
#  'recurso': 6589,
#  'español': 3033,
#  'ente': 2902,
#  'aval': 805,
#  'prevé': 6111,
#  'rechazo': 6508,
#  'izquierdas': 4366,
#  'afrontan': 274,
#  'ciclo': 1353,
#  'político': 5917,
#  'busca': 1053,
#  'liderazgo': 4589,
#  'relación': 6683,
#  'yolanda': 8175,
#  'piensa': 5813,
#  'si': 7182,
#  'candidata': 1147,
#  'presidencia': 6053,
#  'próximas': 6307,
#  'generales': 3642,
#  'unidas': 7798,
#  'claro': 1404,
#  'participar': 5609,
#  'ampliar': 441,
#  'espacio': 3027,
#  'surgido': 7418,
#  'nuevos': 5321,
#  'actores': 137,
#  'compromís': 1585,
#  'andalucismo': 456,
#  'teresa': 7535,
#  'rodríguez': 6921,
#  'entenderse': 2905,
#  'eh': 2728,
#  'bildu': 960,
#  'ribera': 6886,
#  'va': 7864,
#  'pasar': 5636,
#  'frío': 3543,
#  'casa': 1209,
#  'temporada': 7505,
#  'creo': 1975,
#  'vamos': 7903,
#  'problemas': 6154,
#  'centro': 1301,
#  'norte': 5304,
#  'europa': 3159,
#  'cuya': 2082,
#  'principal': 6127,
#  'fuente': 3546,
#  'consumo': 1801,
#  'energético': 2873,
#  'hogares': 3865,
#  'gas': 3625,
#  'procedente': 6157,
#  'rusia': 6966,
#  'señalado': 7171,
#  'compra': 1569,
#  'votos': 8118,
#  'ayuntamiento': 838,
#  'jaén': 4380,
#  'concejal': 1613,
#  'conservador': 1753,
#  'trató': 7708,
#  'comprar': 1571,
#  'voto': 8117,
#  'varias': 7911,
#  'personas': 5777,
#  'según': 7100,
#  'denunciado': 2274,
#  'tarde': 7468,
#  'policía': 5903,
#  'nacional': 5188,
#  'público': 6377,
#  'podido': 5892,
#  'acceder': 72,
#  'conversaciones': 1870,
#  'whatsapp': 8157,
#  'intento': 4253,
#  'condicionar': 1658,
#  'dinero': 2519,
#  'quién': 6426,
#  'podrá': 5893,
#  'recibir': 6519,
#  'ayuda': 832,
#  'industria': 4101,
#  'aprobada': 580,
#  'beneficiarios': 940,
#  'ayudas': 835,
#  'empresas': 2831,
#  'domicilio': 2635,
#  'fiscal': 3461,
#  'territorio': 7549,
#  'realizado': 6476,
#  'menos': 4936,
#  'actividades': 130,
#  'previstas': 6108,
#  'ejercicio': 2742,
#  'ahora': 306,
#  'llegar': 4635,
#  'población': 5877,
#  'campaña': 1126,
#  'vacunación': 7869,
#  'datos': 2133,
#  'reivindica': 6671,
#  'necesidad': 5227,
#  'fuerte': 3548,
#  'combatir': 1487,
#  'intensas': 4243,
#  'prensa': 6012,
#  'extranjera': 3310,
#  'alaba': 320,
#  'laboral': 4477,
#  'medios': 4912,
#  'tan': 7460,
#  'the': 7568,
#  'times': 7577,
#  'dedican': 2198,
#  'artículos': 670,
#  'ministra': 5005,
#  'trabajo': 7645,
#  'diario': 2461,
#  'francés': 3521,
#  'compara': 1526,
#  'eva': 3167,
#  'granados': 3715,
#  'periódico': 5742,
#  'británica': 1029,
#  'destaca': 2393,
#  'reducir': 6600,
#  'precariedad': 5985,
#  'exigen': 3228,
#  'ir': 4332,
#  'playa': 5861,
#  'perros': 5765,
#  'miembros': 4977,
#  'familia': 3360,
#  'coordinadora': 1896,
#  'coruña': 1936,
#  'manuela': 4812,
#  'declarado': 2183,
#  'playas': 5862,
#  'supone': 7404,
#  'ningún': 5273,
#  'tipo': 7578,
#  'riesgo': 6895,
#  'pce': 5666,
#  'denuncian': 2276,
#  'tc': 7481,
#  'voluntad': 8093,
#  'supremo': 7407,
#  'investigar': 4311,
#  'rey': 6880,
#  'emérito': 2832,
#  'amparo': 437,
#  'vulneración': 8138,
#  'derecho': 2304,
#  'tutela': 7756,
#  'judicial': 4413,
#  'efectiva': 2716,
#  'piden': 5804,
#  'nulidad': 5322,
#  'archivo': 624,
#  'querella': 6397,
#  'juan': 4407,
#  'carlos': 1187,
#  'borbón': 1004,
#  'ocho': 5374,
#  'blanqueo': 971,
#  'cohecho': 1448,
#  'relacionados': 6681,
#  'presuntos': 6083,
#  'negocios': 5253,
#  'opacos': 5436,
#  'exjefe': 3246,
#  'condena': 1649,
#  'seguimiento': 7086,
#  'huelga': 3895,
#  'empresa': 2826,
#  'indemnizar': 4079,
#  'euros': 3164,
#  'sindicato': 7222,
#  'haber': 3765,
#  'vulnerado': 8139,
#  'acción': 79,
#  'sindical': 7220,
#  'opone': 5447,
#  'homenaje': 3872,
#  'almudena': 388,
#  'grandes': 3717,
#  'escritora': 3007,
#  'comunista': 1599,
#  'pese': 5790,
#  'moción': 5036,
#  'pasado': 5631,
#  'jueves': 4420,
#  'municipal': 5133,
#  'coalición': 1432,
#  'formado': 3482,
#  'pnc': 5874,
#  'directo': 2540,
#  'presenta': 6031,
#  'candidatura': 1151,
#  'sumar': 7378,
#  'vicepresidenta': 8001,
#  'señal': 7169,
#  'juega': 4416,
#  'víctimas': 8146,
#  'violencia': 8049,
#  'machista': 4725,
#  'atacar': 740,
#  'eduardo': 2707,
#  'rubiño': 6953,
#  'polémico': 5912,
#  'tuit': 7743,
#  'publicado': 6320,
#  'coincidiendo': 1453,
#  'inicio': 4160,
#  'navidad': 5217,
#  'dirige': 2545,
#  'afirma': 261,
#  'rita': 6902,
#  'maestre': 4739,
#  'agresores': 295,
#  'sexuales': 7167,
#  'tocado': 7589,
#  'gordo': 3700,
#  'asegura': 677,
#  'tomará': 7605,
#  'carácter': 1208,
#  'inmediato': 4170,
#  'futuro': 3575,
#  'primer': 6119,
#  'acto': 135,
#  'escucha': 3011,
#  'proyecto': 6293,
#  'andalucía': 458,
#  'expresado': 3281,
#  'espera': 3054,
#  'sirva': 7229,
#  'contribuir': 1852,
#  'país': 5664,
#  'esperanza': 3061,
#  'gente': 3651,
#  'pasando': 5634,
#  'mal': 4752,
#  'centra': 1293,
#  'andaluzas': 461,
#  'partidos': 5623,
#  'sientan': 7186,
#  'sortear': 7309,
#  'consecuencias': 1731,
#  'fiasco': 3411,
#  'registro': 6650,
#  'legal': 4521,
#  'dejó': 2237,
#  'alianza': 375,
#  'saca': 6987,
#  'pecho': 5669,
#  'bajada': 858,
#  'iva': 4363,
#  'acusa': 170,
#  'van': 7904,
#  'plan': 5838,
#  'bajar': 859,
#  'mínimo': 5172,
#  'dicen': 2465,
#  'populares': 5935,
#  'asuma': 728,
#  'propuestas': 6255,
#  'apoyar': 567,
#  'prórroga': 6303,
#  'anticrisis': 487,
#  'entrega': 2928,
#  'cortes': 1932,
#  'castilla': 1223,
#  'león': 4568,
#  'día': 2677,
#  'gallego': 3597,
#  'defendió': 2208,
#  'razonable': 6453,
#  'votada': 8107,
#  'mostró': 5095,
#  'gobiernos': 3690,
#  'salen': 7009,
#  'despachos': 2377,
#  'plantea': 5847,
#  'recurrir': 6586,
#  'apoyará': 569,
#  'decide': 2165,
#  'hacerlo': 3789,
#  'aclarado': 96,
#  'cuál': 2086,
#  'parlamentario': 5595,
#  'pah': 5537,
#  'inicia': 4150,
#  'exigir': 3233,
#  'cumplimiento': 2068,
#  'catalana': 1226,
#  'iniciativa': 4158,
#  'así': 738,
#  'cosas': 1938,
#  'reclama': 6529,
#  'aprobación': 579,
#  'definitiva': 2221,
#  'estatal': 3099,
#  'acabe': 64,
#  'especulación': 3049,
#  'inmobiliaria': 4176,
#  'buitre': 1046,
#  'aborto': 32,
#  'llega': 4629,
#  'tribunales': 7720,
#  'abogados': 23,
#  'cristianos': 1986,
#  'planteado': 5850,
#  'veintena': 7936,
#  'denuncias': 2283,
#  'juzgados': 4462,
#  'toda': 7591,
#  'españa': 3032,
#  'clínicas': 1424,
#  'alegando': 350,
#  'información': 4121,
#  'correcta': 1912,
#  'ferraz': 3404,
#  'fracasa': 3508,
#  'intentar': 4249,
#  'única': 8229,
#  'mercedes': 4951,
#  'gonzález': 3698,
#  'tres': 7716,
#  'candidatos': 1150,
#  'nombre': 5293,
#  'delegada': 2241,
#  'acogida': 103,
#  'ex': 3187,
#  'alcalde': 331,
#  'soto': 7320,
#  'real': 6467,
#  'lobato': 4669,
#  'fuenlabrada': 3545,
#  'javier': 4379,
#  'secretaria': 7067,
#  'general': 3641,
#  'creen': 1972,
#  'competir': 1551,
#  'proceso': 6167,
#  'aspirantes': 724,
#  'dirección': 2533,
#  'federal': 3388,
#  'moncloa': 5062,
#  'insiste': 4190,
#  'precios': 5989,
#  'alimentos': 381,
#  'casi': 1214,
#  'cuatro': 2027,
#  'meses': 4960,
#  'vemos': 7940,
#  'contención': 1817,
#  'debería': 2152,
#  'conducir': 1661,
#  'reducción': 6597,
#  'agricultura': 297,
#  'luis': 4706,
#  'planas': 5839,
#  'últimos': 8228,
#  'conocidos': 1718,
#  'mes': 4957,
#  'ninguna': 5271,
#  'medida': 4907,
#  'adicional': 194,
#  'audiencia': 758,
#  'rechaza': 6501,
#  'reabrir': 6459,
#  'villarejo': 8032,
#  'corinna': 1903,
#  'larsen': 4504,
#  'jueces': 4415,
#  'acreditar': 121,
#  'siquiera': 7227,
#  'estadio': 3089,
#  'inicial': 4152,
#  'espiar': 3065,
#  'llamadas': 4614,
#  'teléfono': 7497,
#  'correos': 1917,
#  'electrónicos': 2762,
#  'sindicatos': 7223,
#  'presión': 6069,
#  'bloqueo': 980,
#  'firmado': 3452,
#  'garantía': 3620,
#  'digna': 2501,
#  'adecuada': 184,
#  'impulsada': 4000,
#  'organizaciones': 5475,
#  'civil': 1398,
#  'hacer': 3787,
#  'materia': 4871,
#  'griñán': 3730,
#  'irá': 4346,
#  'constitucional': 1781,
#  'defenderse': 2203,
#  'pena': 5691,
#  'ere': 2967,
#  'abogado': 22,
#  'confirma': 1679,
#  'presentarán': 6045,
#  'anuncio': 511,
#  'fallo': 3350,
#  'letrados': 4552,
#  'oponen': 5448,
#  'investigue': 4313,
#  'fortuna': 3498,
#  'venta': 7954,
#  'armas': 643,
#  'alegan': 349,
#  'avalar': 809,
#  'creación': 1953,
#  'comisión': 1523,
#  'investigación': 4302,
#  'destinado': 2405,
#  'esclarecer': 2991,
#  'vendió': 7947,
#  'países': 5665,
#  'árabes': 8202,
#  'exclusiva': 3205,
#  'nuevas': 5318,
#  'generaciones': 3637,
#  'vale': 7877,
#  'malo': 4758,
#  'conocido': 1717,
#  'bueno': 1042,
#  'conocer': 1713,
#  'diputada': 2528,
#  'pronunció': 6231,
#  'frase': 3525,
#  'favor': 3375,
#  'comisario': 1517,
#  'castaño': 1217,
#  'kitchen': 4474,
#  'juicio': 4429,
#  'unidad': 7796,
#  'central': 1296,
#  'operativo': 5443,
#  'muchas': 5111,
#  'cuestiones': 2048,
#  'planteadas': 5849,
#  'actitud': 124,
#  'primera': 6120,
#  'comparecencia': 1530,
#  'guerra': 3746,
#  'casado': 1211,
#  'coronavirus': 1905,
#  'comunidad': 1596,
#  'libertad': 4574,
#  'evitar': 3183,
#  'eventos': 3171,
#  'prudencia': 6295,
#  'contagios': 1809,
#  'fechas': 3385,
#  'lanzará': 4497,
#  'próxima': 6305,
#  'inspección': 4197,
#  'atajar': 742,
#  'fraude': 3527,
#  'segunda': 7091,
#  'avanza': 815,
#  'pondrá': 5919,
#  'marcha': 4828,
#  'utilizado': 7855,
#  'usar': 7840,
#  'tirar': 7581,
#  'turismo': 7748,
#  'laura': 4509,
#  'psn': 6312,
#  'dice': 2464,
#  'pamplona': 5548,
#  'foral': 3475,
#  'navarra': 5215,
#  'feudo': 3407,
#  'embargo': 2795,
#  'tendencia': 7511,
#  'cambiado': 1114,
#  'rumbo': 6961,
#  'legislaturas': 4531,
#  'progresistas': 6204,
#  'pasadas': 5630,
#  'dieron': 2479,
#  'triunfo': 7727,
#  'socialista': 7260,
#  'navarro': 5216,
#  'mayoría': 4887,
#  'simple': 7217,
#  'necesitaba': 5230,
#  'apoyos': 574,
#  'sentido': 7126,
#  'chivite': 1345,
#  'pudo': 6331,
#  'abstención': 45,
#  'mayo': 4882,
#  'volverá': 8099,
#  'ser': 7142,
#  'clave': 1410,
#  'repetir': 6729,
#  'pesar': 5788,
#  'upn': 7817,
#  'pueda': 6335,
#  'ganar': 3608,
#  'entrevista': 2935,
#  'puede': 6337,
#  'progresista': 6203,
#  'lesmes': 4547,
#  'reunión': 6858,
#  'urgencia': 7829,
#  'renovar': 6712,
#  'cgpj': 1329,
#  'poder': 5887,
#  'amenazado': 424,
#  'adopción': 220,
#  'decisiones': 2175,
#  'queremos': 6399,
#  'gustan': 3754,
#  'conde': 1646,
#  'compañeros': 1544,
#  'crear': 1958,
#  'grave': 3721,
#  'pandemias': 5554,
#  'particular': 5614,
#  'magistrado': 4745,
#  'carga': 1176,
#  'criterio': 1990,
#  'alarma': 322,
#  'deja': 2224,
#  'sola': 7270,
#  'pronunciarse': 6229,
#  'abierta': 14,
#  'pública': 6374,
#  'provocado': 6287,
#  'echa': 2684,
#  'claves': 1411,
#  'xavier': 8160,
#  'trias': 7717,
#  'alcaldía': 334,
#  'barcelona': 894,
#  'comú': 1606,
#  'quinta': 6416,
#  'vez': 7987,
#  'liderar': 4587,
#  'ciudad': 1391,
#  'presentará': 6044,
#  'ada': 181,
#  'colau': 1462,
#  'antiguo': 493,
#  'vuelve': 8131,
#  'arma': 638,
#  'desviar': 2419,
#  'atención': 745,
#  'crisis': 1983,
#  'visita': 8061,
#  'anunciar': 508,
#  'batería': 919,
#  'acciones': 78,
#  'adoctrinamiento': 217,
#  'aulas': 766,
#  'mar': 4815,
#  'justo': 4456,
#  'enfrentamiento': 2884,
#  'entra': 2919,
#  'fase': 3373,
#  'decisiva': 2176,
#  'mucha': 5110,
#  'igualdad': 3945,
#  'encuestas': 2866,
#  'ola': 5418,
#  'azul': 844,
#  'suceder': 7339,
#  'continúa': 1835,
#  'medidas': 4908,
#  'reúne': 6883,
#  'málaga': 5151,
#  'dirigentes': 2547,
#  'ciudadanos': 1395,
#  'policial': 5901,
#  'hicieron': 3836,
#  'marca': 4818,
#  'cinco': 1373,
#  'todavía': 7593,
#  'juzgado': 4461,
#  'centros': 1303,
#  'electorales': 2756,
#  'agentes': 283,
#  'investigados': 4308,
#  'actuaciones': 140,
#  'votantes': 8111,
#  'heridos': 3822,
#  'reconocen': 6548,
#  'aunque': 774,
#  'recuperado': 6579,
#  'lesiones': 4545,
#  'físicas': 3582,
#  'reparación': 6721,
#  'llegará': 4637,
#  'capítulo': 1170,
#  'cerrado': 1318,
#  'palabra': 5538,
#  'insultos': 4227,
#  'patricia': 5653,
#  'rueda': 6955,
#  'negado': 5237,
#  'retirar': 6832,
#  'ocasiones': 5371,
#  'vicepresidente': 8002,
#  'primero': 6122,
#  'alfonso': 366,
#  'pedido': 5670,
#  'tribuna': 7718,
#  'impulsará': 4004,
#  'mociones': 5035,
#  'indultos': 4100,
#  'presos': 6071,
#  'procés': 6171,
#  'conservadores': 1755,
#  'anunciado': 505,
#  'independentistas': 4083,
#  'instrumentos': 4221,
#  'alcance': 337,
#  'utilizando': 7858,
#  'incluso': 4045,
#  'anti': 482,
#  'lgtbi': 4570,
#  'apoya': 562,
#  'ue': 7779,
#  'fuerzas': 3551,
#  'únicos': 8233,
#  'comunitario': 1602,
#  'eurocámara': 3154,
#  'bruselas': 1036,
#  'fondos': 3474,
#  'europeos': 3163,
#  'respete': 6790,
#  'derechos': 2305,
#  'fundamentales': 3566,
#  'sectores': 7075,
#  'andaluz': 459,
#  'critican': 1995,
#  'espadas': 3029,
#  'quiera': 6406,
#  'aprobar': 584,
#  'único': 8232,
#  'quedar': 6384,
#  'toni': 7613,
#  'valero': 7886,
#  'situación': 7238,
#  'reto': 6839,
#  'políticas': 5916,
#  'apenas': 538,
#  'celaá': 1268,
#  'trataba': 7694,
#  'esperada': 3056,
#  'magistrados': 4746,
#  'presentado': 6036,
#  'etapa': 3145,
#  'marcada': 4819,
#  'giro': 3674,
#  'ultraderecha': 7787,
#  'primarias': 6117,
#  'propuso': 6258,
#  'recuperar': 6581,
#  'idea': 3921,
#  'ilegalizar': 3954,
#  'anunció': 513,
#  'enmienda': 2893,
#  'totalidad': 7632,
#  'memoria': 4924,
#  'histórica': 3857,
#  'miedo': 4975,
#  'india': 4087,
#  'fuerza': 3550,
#  'adelanto': 191,
#  'dosis': 2647,
#  'astrazeneca': 725,
#  'transmisión': 7674,
#  'comunitaria': 1601,
#  'covid': 1951,
#  'convierta': 1876,
#  'semanas': 7106,
#  'salud': 7029,
#  'antonio': 496,
#  'ribó': 6887,
#  'vías': 8144,
#  'abusos': 57,
#  'iglesia': 3940,
#  'pone': 5921,
#  'fuentes': 3547,
#  'incluir': 4041,
#  'parlamentarios': 5596,
#  ...}

# %%
import numpy as np

X = np.zeros((data_procesada.shape[0], 30))
for i,corp in enumerate(corpus):
    vect = np.zeros(100)
    for num,word in enumerate(corp.split(' ')):
        try:
            vect += model[word]*TF_IDF[i,tf_idf[word]]
        except:
            pass
    if num != 0:
        vect = vect/num
    else:
        vect = vect * 0
    vect = vect.reshape(1,100)
    vect_pca = pca.transform(vect)
    X[i,:]=vect_pca

# %%
Y = data_procesada['Categoria'].values

tt = int(0.9 * len(X))
X_train, X_test = X[:tt], X[tt:]
y_train, y_test = Y[:tt], Y[tt:]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:981: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(self.var_), copy=False, constant_mask=constant_mask

# %%
from sklearn import svm

best_kernel = 0
best_degree = 0
best_gamma = 0
best_C = 0
best_accuracy = 0

kernels = ['rbf', 'sigmoid', 'poly']
degrees = [1, 2, 3, 4, 5]
gammas = [0.0001, 0.001, 0.01, 0.1, 1.0, 2.0]
values_of_C = [1.0e-4, 1.0e-3, 1.0e-2, 1.0e-1, 1.0, 1.0e+1, 1.0e+2, 1.0e+3]
coef0 = 1.0

print("Probando hiperparametros")
for kernel in kernels:
    if kernel == 'poly':
        _degrees = degrees
    else:
        _degrees = [1]
    for degree in degrees:
        for gamma in gammas:
            for C in values_of_C:
                classifier = svm.SVC(kernel=kernel, degree=degree, gamma=gamma, coef0=coef0, C=C, max_iter=100)
                classifier.fit(X_train, y_train)
                y_pred = classifier.predict(X_test)

                accuracy = (100 * (y_test == y_pred).sum()) / (len(y_test))

                if accuracy > best_accuracy:
                    best_accuracy = accuracy
                    best_kernel = kernel
                    best_gamma = gamma
                    best_C = C
                    best_degree = degree
                print(" %-7s degree %3d gamma %.6f C %e accuracy %.1f%%" % (kernel, degree, gamma, C, accuracy))
print("La mejor combinación es: %-7s degree %3d gamma %.6f C %e accuracy %.1f%%" % (best_kernel, best_degree, best_gamma, best_C, best_accuracy))

# %% [markdown]
# ### Modelo de Redes Neuronales

# %%
x_train, x_test = X_train.reshape(X_train.shape[0], 1, X_train.shape[1]), X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
y = np.eye(2)[Y]
Y_train, Y_test = y[:tt], y[tt:]

# %%
import keras
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Reshape, Flatten, Activation
from keras.layers import Dropout, BatchNormalization, GaussianNoise
from keras.layers import Dense, LSTM
from keras.constraints import max_norm
from keras.optimizers import RMSprop, SGD, Adadelta, Adagrad, Adam

# %%
_tensor_ = input_tensor = Input(shape=(1, x_train.shape[2]), name='main_input')

_tensor_ = LSTM(51, activation='relu', kernel_constraint=max_norm(3.0), return_sequences=True)(_tensor_)

_tensor_ = Flatten()(_tensor_)

_tensor_ = Dense(500, activation='relu', kernel_constraint=max_norm(3.0))(_tensor_)
_tensor_ = Dense(500, activation='relu', kernel_constraint=max_norm(3.0))(_tensor_)
_tensor_ = Dense(100, activation='relu', kernel_constraint=max_norm(3.0))(_tensor_)

output_tensor = Dense(2, activation='sigmoid', kernel_constraint=max_norm(3.0))(_tensor_)

model = Model(input_tensor, output_tensor)
model.compile(loss='mse', optimizer=Adagrad())
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape              ┃    Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ main_input (InputLayer)         │ (None, 1, 30)             │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ lstm_1 (LSTM)                   │ (None, 1, 51)             │     16,728 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ flatten (Flatten)               │ (None, 51)                │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dense (Dense)                   │ (None, 500)               │     26,000 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dense_1 (Dense)                 │ (None, 500)               │    250,500 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dense_2 (Dense)                 │ (None, 100)               │     50,100 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dense_3 (Dense)                 │ (None, 2)                 │        202 │
# └─────────────────────────────────┴───────────────────────────┴────────────┘
#  Total params: 343,530 (1.31 MB)
#  Trainable params: 343,530 (1.31 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train, Y_train, batch_size=100, epochs=300, shuffle=True, verbose=1)
# Out:
# Epoch 1/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2492
# Epoch 2/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2469
# Epoch 3/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2458
# Epoch 4/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2448
# Epoch 5/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2442
# Epoch 6/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 7/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2434
# Epoch 8/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2428
# Epoch 9/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2439
# Epoch 10/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 11/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 12/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 13/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 14/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 15/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2426
# Epoch 16/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 17/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 18/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 19/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 20/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 21/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 22/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 23/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 24/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 25/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 26/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 27/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 28/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 29/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 30/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 31/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 32/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 33/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2431
# Epoch 34/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 35/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 36/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2433
# Epoch 37/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 38/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 39/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 40/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2426
# Epoch 41/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 42/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2438
# Epoch 43/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2432
# Epoch 44/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2438
# Epoch 45/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2431
# Epoch 46/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2439
# Epoch 47/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2423
# Epoch 48/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2427
# Epoch 49/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2433
# Epoch 50/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 51/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2440
# Epoch 52/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 53/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 54/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 55/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2426
# Epoch 56/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 57/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 58/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 59/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 60/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 61/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 62/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2440
# Epoch 63/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 64/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2430
# Epoch 65/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2426
# Epoch 66/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 67/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2439
# Epoch 68/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 69/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 70/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2437
# Epoch 71/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2439
# Epoch 72/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2439
# Epoch 73/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2441
# Epoch 74/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 75/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 76/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 77/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2433
# Epoch 78/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2438
# Epoch 79/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 80/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2427
# Epoch 81/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 82/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 83/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 84/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 85/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 86/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2426
# Epoch 87/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2435
# Epoch 88/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2433
# Epoch 89/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 90/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 91/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 92/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2430
# Epoch 93/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 94/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 95/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 96/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 97/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 98/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 99/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 100/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2435
# Epoch 101/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2438
# Epoch 102/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 103/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2436
# Epoch 104/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 105/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2432
# Epoch 106/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2428
# Epoch 107/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 108/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2436
# Epoch 109/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 110/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 111/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2436
# Epoch 112/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2432
# Epoch 113/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 114/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 115/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2432
# Epoch 116/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 117/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 118/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 119/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 120/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 121/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2426
# Epoch 122/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2437
# Epoch 123/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 124/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2431
# Epoch 125/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 126/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 127/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2426
# Epoch 128/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 129/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 130/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 131/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 132/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 133/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 134/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 135/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 136/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 137/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 138/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2424
# Epoch 139/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 140/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 141/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2427
# Epoch 142/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 143/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 144/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2439
# Epoch 145/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 146/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 147/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 148/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2424
# Epoch 149/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 150/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 151/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 152/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 153/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 154/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 155/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 156/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 157/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 158/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2438
# Epoch 159/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 160/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 161/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 162/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 163/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 164/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 165/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 166/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 167/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 168/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 169/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 170/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 171/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 172/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 173/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 174/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2427
# Epoch 175/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 176/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 177/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 178/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 179/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 180/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 181/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2426
# Epoch 182/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2431
# Epoch 183/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2434
# Epoch 184/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 185/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 186/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 187/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 188/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2427
# Epoch 189/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 190/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 191/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 192/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 193/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 194/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 195/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2436
# Epoch 196/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 197/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 198/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 199/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 200/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2427
# Epoch 201/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 202/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 203/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 204/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 205/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 206/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 207/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2441
# Epoch 208/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 209/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2426
# Epoch 210/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 211/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 212/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 213/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 214/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 215/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 216/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 217/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 218/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 219/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 220/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 221/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 222/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 223/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 224/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 225/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 226/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 227/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2429
# Epoch 228/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 229/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 230/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 231/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2439
# Epoch 232/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 233/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 234/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 235/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2426
# Epoch 236/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 237/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 238/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 239/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 240/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2438
# Epoch 241/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 242/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2427
# Epoch 243/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 244/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 245/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2427
# Epoch 246/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 247/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2427
# Epoch 248/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2441
# Epoch 249/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2430
# Epoch 250/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2436
# Epoch 251/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2429
# Epoch 252/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 253/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 254/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 255/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 256/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 257/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 258/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 259/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 260/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 261/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 262/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 263/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 264/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2432
# Epoch 265/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 266/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 267/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 268/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2437
# Epoch 269/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 270/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2426
# Epoch 271/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 272/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 273/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436
# Epoch 274/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 275/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 276/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2425
# Epoch 277/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 278/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 279/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 280/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 281/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 282/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 283/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 284/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 285/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 286/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 287/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 288/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 289/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 290/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432
# Epoch 291/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2428
# Epoch 292/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 293/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2439
# Epoch 294/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2434
# Epoch 295/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2433
# Epoch 296/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2431
# Epoch 297/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2435
# Epoch 298/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2430
# Epoch 299/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429
# Epoch 300/300
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2432

# %%
y_pred = np.zeros(y_test.shape[0])
for i,case in enumerate(model.predict(x_test)):
    y_pred[i] = case.argmax()
# Out:
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step

# %%
accuracy = (100.0 * (y_test == y_pred).sum()) / len(Y_test)

# %%
accuracy
# Out:
# 51.68307399174341
